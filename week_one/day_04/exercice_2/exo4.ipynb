# %%
# import utils packages
import pandas as pd
import numpy as np

file_to_extract = "E:/data_analyst/week_one/day_04/exercice_2/data/clients.csv"

clients = pd.read_csv(file_to_extract, nrows=20)

def csv_file_reader(file_path):
    result = pd.read_csv(file_path)
    return result

def count_nullls(df):
    return df.isnull().sum()

def df_length(df):
    return len(df)
    

def audit_nulls(df, name):
    nulls = count_nullls(df)
    nulls = nulls[nulls > 0]
    pct = (nulls / df_length(df) * 100).round(1)
    
    result = pd.DataFrame({'manquantes': nulls, 'pct_%': pct})
    
    print(f'\n=== {name} ===')
    print(result if len(result) > 0 else 'Aucun valeurs manquantes')
    
# def clean_df(df):
    
   
clients.head(20)
# Out:
#     id_client                    nom                 email    telephone  \
# 0           1            Aina Rakoto       aina1@gmail.com  325614226.0
# 1           2            Hery Andria       hery2@gmail.com  324335942.0
# 2           3               Soa Rabe       soa3@gmail.com        3266.0
# 3           4         Tojo Ravelona        tojo4@gmail.com  347067228.0
# 4           5          Manda Randria       manda5@gmail.cm  332197935.0
# 5           6          Fara Rasolofo       fara6@gmail.com  324842788.0
# 6           7             Noro Rasoa       noro7@gmail.com  333396987.0
# 7           8       Lala Andriantsoa       lala8@gmail.com       3228.0
# 8           9      Dina Rakotondrabe       dina9@gmail.com  325476583.0
# 9          10      Koto Ratsimbazafy      koto10@gmail.com          NaN
# 10         11    Rina Razafimandimby      rina11@gmail.com       3350.0
# 11         12      Bako Rakotonirina     bako12@gmail.com   348099076.0
# ...
